# %%
import pandas as pd  #importing pandas

# %%
ckd = pd.read_csv("Assignment Material/Dataset/chronic_kidney_disease_full.csv")

# %%
ckd[['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wbcc', 'rbcc', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane', 'class']]
# Out:
#       age     bp     sg   al   su       rbc        pc         pcc          ba  \
# 0     NaN    NaN    NaN  NaN  NaN       NaN       NaN         NaN         NaN
# 1    48.0   80.0  1.020  1.0  0.0       NaN    normal  notpresent  notpresent
# 2     7.0   50.0  1.020  4.0  0.0       NaN    normal  notpresent  notpresent
# 3    62.0   80.0  1.010  2.0  3.0    normal    normal  notpresent  notpresent
# 4    48.0   70.0  1.005  4.0  0.0    normal  abnormal     present  notpresent
# 5    51.0   80.0  1.010  2.0  0.0    normal    normal  notpresent  notpresent
# 6    60.0   90.0  1.015  3.0  0.0       NaN       NaN  notpresent  notpresent
# 7    68.0   70.0  1.010  0.0  0.0       NaN    normal  notpresent  notpresent
# 8    24.0    NaN  1.015  2.0  4.0    normal  abnormal  notpresent  notpresent
# 9    52.0  100.0  1.015  3.0  0.0    normal  abnormal     present  notpresent
# 10   53.0   90.0  1.020  2.0  0.0  abnormal  abnormal     present  notpresent
# ...

# %% [markdown]
# Printed columns: ['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wbcc', 'rbcc', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane', 'class']

# %%
ckd[1:6] #first five rows
# Out:
#     age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 1  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 2   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 3  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 4  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 5  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#      bgr  ...    pcv    wbcc  rbcc  htn    dm  cad  appet   pe  ane class
# 1  121.0  ...   44.0  7800.0   5.2  yes  ?yes   no   good   no   no   ckd
# 2    NaN  ...   38.0  6000.0   NaN   no    no   no   good   no   no   ckd
# 3  423.0  ...   31.0  7500.0   NaN   no   yes   no   poor   no  yes   ckd
# 4  117.0  ...   32.0  6700.0   3.9  yes    no   no   poor  yes  yes   ckd
# 5  106.0  ...   35.0  7300.0   4.6   no    no   no   good   no   no   ckd
#
# [5 rows x 25 columns]

# %%
ckd.dm.unique() #to check unique values.
# Out:
# array([nan, '?yes', 'no', 'yes'], dtype=object)

# %% [markdown]
# There is an abnormal value "?yes", so the dataset is not clean.

# %%
ckd.groupby('dm').dm.count() # to check how many entries are abnormal
# Out:
# dm
# ?yes      1
# no      261
# yes     136
# Name: dm, dtype: int64

# %%
ckd.where(ckd['dm']=='?yes').count()
# Out:
# age      1
# bp       1
# sg       1
# al       1
# su       1
# rbc      0
# pc       1
# pcc      1
# ba       1
# bgr      1
# bu       1
# sc       1
# sod      0
# pot      0
# hemo     1
# pcv      1
# wbcc     1
# rbcc     1
# htn      1
# dm       1
# cad      1
# appet    1
# pe       1
# ane      1
# class    1
# dtype: int64
